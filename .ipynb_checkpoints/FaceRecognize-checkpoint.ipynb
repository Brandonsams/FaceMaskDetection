# %%
import cv2
import pandas as pd
import os
import shutil
import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
(width, height) = (128, 128)
batch_size = 16

# %%
df = pd.read_csv("annotations.csv")

# %%
df
# Out:
#                 filename  width  height                  class  xmin  ymin  \
# 0      maksssksksss0.png    512     366           without_mask    79   105
# 1      maksssksksss0.png    512     366              with_mask   185   100
# 2      maksssksksss0.png    512     366           without_mask   325    90
# 3      maksssksksss1.png    400     156              with_mask   321    34
# 4      maksssksksss1.png    400     156              with_mask   224    38
# ...                  ...    ...     ...                    ...   ...   ...
# 4067  maksssksksss98.png    400     267              with_mask   263    62
# 4068  maksssksksss98.png    400     267              with_mask   344    80
# 4069  maksssksksss99.png    400     267  mask_weared_incorrect   181    54
# 4070  maksssksksss99.png    400     267              with_mask    99    87
# 4071  maksssksksss99.png    400     267              with_mask   289    99
#
#       xmax  ymax
# 0      109   142
# 1      226   144
# 2      360   141
# 3      354    69
# 4      261    73
# ...    ...   ...
# 4067   287    85
# 4068   377   106
# 4069   273   162
# 4070   176   165
# 4071   355   233
#
# [4072 rows x 8 columns]

# %%
    # Uncomment this section to save images in color

    def save_cropped_image(index, row):
        img = cv2.imread(f"./Kaggle-MaskDetection/images/{row['filename']}")
        crop_img = img[row['ymin']:row['ymax'], row['xmin']:row['xmax']]
        resized_img = cv2.resize(crop_img, (width, height))
        if not os.path.exists(f"./Kaggle-MaskDetection/cropped/{row['class']}"):
            os.makedirs(f"./Kaggle-MaskDetection/cropped/{row['class']}")
        cv2.imwrite(f"./Kaggle-MaskDetection/cropped/{row['class']}/{index}-{row['filename']}", resized_img)

# %%
# def save_cropped_image(index, row):
#     img = cv2.imread(f"./Kaggle-MaskDetection/images/{row['filename']}")
#     crop_img = img[row['ymin']:row['ymax'], row['xmin']:row['xmax']]
#     grayImage = cv2.cvtColor(crop_img, cv2.COLOR_BGR2GRAY)
#     resized_img = cv2.resize(grayImage, (width, height))
#     if not os.path.exists(f"./Kaggle-MaskDetection/cropped/{row['class']}"):
#         os.makedirs(f"./Kaggle-MaskDetection/cropped/{row['class']}")
#     cv2.imwrite(f"./Kaggle-MaskDetection/cropped/{row['class']}/{index}-{row['filename']}", resized_img)

# %%
if os.path.exists('./Kaggle-MaskDetection/cropped'):
    shutil.rmtree('./Kaggle-MaskDetection/cropped')

if not os.path.exists('./Kaggle-MaskDetection/cropped'):
    os.makedirs('./Kaggle-MaskDetection/cropped')
    
for index, row in df.iterrows():
    save_cropped_image(index,row)

# %%
data_dir = f"./Kaggle-MaskDetection/cropped"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(width, height),
  batch_size=batch_size)
# Out:
# Found 4072 files belonging to 3 classes.
# Using 3258 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(width, height),
  batch_size=batch_size)
# Out:
# Found 4072 files belonging to 3 classes.
# Using 814 files for validation.

# %%
train_ds
# Out:
# <BatchDataset shapes: ((None, 128, 128, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
import matplotlib.pyplot as plt

class_names = train_ds.class_names
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 128, 128, 3)
# (16,)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalization_layer

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.027450982 0.9960785

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = 3

model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=50
)
# Out:
# Epoch 1/10
# 204/204 [==============================] - 92s 449ms/step - loss: 0.3444 - accuracy: 0.8859 - val_loss: 0.2146 - val_accuracy: 0.9238
# Epoch 2/10
# 204/204 [==============================] - 81s 396ms/step - loss: 0.2120 - accuracy: 0.9342 - val_loss: 0.2115 - val_accuracy: 0.9251
# Epoch 3/10
# 204/204 [==============================] - 68s 334ms/step - loss: 0.1748 - accuracy: 0.9450 - val_loss: 0.2075 - val_accuracy: 0.9275
# Epoch 4/10
# 204/204 [==============================] - 66s 325ms/step - loss: 0.1626 - accuracy: 0.9407 - val_loss: 0.2000 - val_accuracy: 0.9337
# Epoch 5/10
# 204/204 [==============================] - 64s 314ms/step - loss: 0.1538 - accuracy: 0.9481 - val_loss: 0.1991 - val_accuracy: 0.9300
# Epoch 6/10
# 204/204 [==============================] - 69s 340ms/step - loss: 0.1508 - accuracy: 0.9432 - val_loss: 0.2043 - val_accuracy: 0.9263
# Epoch 7/10
# 204/204 [==============================] - 82s 402ms/step - loss: 0.1403 - accuracy: 0.9508 - val_loss: 0.2079 - val_accuracy: 0.9324
# Epoch 8/10
# 204/204 [==============================] - 62s 299ms/step - loss: 0.1249 - accuracy: 0.9597 - val_loss: 0.2143 - val_accuracy: 0.9361
# Epoch 9/10
# 204/204 [==============================] - 71s 348ms/step - loss: 0.1201 - accuracy: 0.9617 - val_loss: 0.1976 - val_accuracy: 0.9324
# Epoch 10/10
# 204/204 [==============================] - 73s 360ms/step - loss: 0.1102 - accuracy: 0.9658 - val_loss: 0.2645 - val_accuracy: 0.9361

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy - Color')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('./WhitePaperImages/Model Accuracy - Color.png', dpi=500, transparent=False)
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss - Color')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('./WhitePaperImages/Model Loss - Color.png', dpi=500, transparent=False)
plt.show()
